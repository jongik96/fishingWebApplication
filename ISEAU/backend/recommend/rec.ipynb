# %%
import pandas as pd


datas = pd.read_csv('../data/Reviewdata.csv')
sort_datas = datas.sort_values(by=['userId', 'fishingId'], ascending=[True, True])
# temp = sort_datas['fishingId']
temp = sort_datas["userId"][0]
print(temp)
# for data in sort_datas.iterrows():
#     print(data[1]['fishingId'])


# sort_datas
datas
# Out:
# 1752
#          id  userId  fishingId  rating  \
# 0         1    1752        277       3
# 1         2    1306        410       2
# 2         3     344       1057       5
# 3         4    1623        984       4
# 4         5     605       1135       1
# ...     ...     ...        ...     ...
# 9995   9996    1795       1187       3
# 9996   9997    1156        741       4
# 9997   9998     537        479       4
# 9998   9999    1045       1126       1
# 9999  10000     594        939       1
#
#                                           reviewContent   createdAt
# 0     at dolor quis odio consequat varius integer ac...  2020-03-28
# 1     fermentum justo nec condimentum neque sapien p...  2021-08-29
# 2     at nibh in hac habitasse platea dictumst aliqu...  2019-01-03
# 3     felis ut at dolor quis odio consequat varius i...  2019-06-10
# 4     mauris lacinia sapien quis libero nullam sit a...  2020-01-05
# ...                                                 ...         ...
# ...
