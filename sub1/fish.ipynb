# %%
import pandas as pd
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)
data=pd.read_csv("./어종.csv")
data
# Out:
#        NO       SPEC         MEAN
# 0   F0001        가리비          NaN
# 1   F0002  가무락(모시조개)          NaN
# 2   F0003        가자미          NaN
# 3   F0004        간재미           원투
# 4   F0005         갈치          NaN
# 5   F0006        감성돔     릴찌,장대,원투
# 6   F0007       갑오징어           에깅
# 7   F0008         개불          NaN
# 8   F0009          게          NaN
# 9   F0010         고동          NaN
# 10  F0011        고등어     장대,릴찌,루어
# 11  F0012         광어        릴찌,원투
# 12  F0013          굴          NaN
# 13  F0014       까막조개          NaN
# 14  F0015         꼬막          NaN
# 15  F0016       꼬시래기          NaN
# 16  F0017        꼴뚜기          NaN
# 17  F0018         꽁치        릴찌,장대
# 18  F0019         꽃게          NaN
# 19  F0020         낙지          NaN
# 20  F0021         넙치        루어,원투
# 21  F0022        노래미  루어,릴찌,장대,원투
# 22  F0023         농게          NaN
# 23  F0024         농어        루어,릴찌
# 24  F0025       다금바리           원투
# 25  F0026        도다리           원투
# ...

# %%
import pandas as pd
pd.set_option('display.max_columns',None)
data=pd.read_csv("./new선상.csv")
data
# Out:
#               X          Y OBJECTID YINFO_ID     GID             NAME  \
# 0    126.286306  33.969250   S20099    F2042  214985              추자도
# 1    126.284583  33.962639   S20100    F2042  214986              추자도
# 2    126.665194  33.552611   S20101    F2045  214987           제주도 북부
# 3    126.701722  33.560111   S20102    F2045  214988           제주도 북부
# 4    126.775139  33.576639   S20103    F2046  214989       제주도 북동부·우도
# 5    126.933083  33.524306   S20104    F2046  214990       제주도 북동부·우도
# 6    126.921917  33.508167   S20105    F2046  214991       제주도 북동부·우도
# 7    126.941306  33.485472   S20106    F2046  214992       제주도 북동부·우도
# 8    126.934583  33.501306   S20107    F2046  214993       제주도 북동부·우도
# 9    126.947167  33.529861   S20108    F2046  214994       제주도 북동부·우도
# 10   126.970417  33.523583   S20109    F2046  214995       제주도 북동부·우도
# 11   126.952139  33.455806   S20110    F2047  214996           제주도 동부
# ...
