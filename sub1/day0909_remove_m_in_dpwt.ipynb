# %%
import pandas as pd
pd.set_option('display.max_columns',None)
data=pd.read_csv("./new갯바위.csv")
data
# Out:
#               X          Y OBJECTID YINFO_ID            NAME       POINT_NM  \
# 0    127.453694  34.543694   G10392    F1026             나로도  내나로도 구룡마을 갯바위
# 1    126.223750  33.411694   G20695    F2043  제주도 서부·차귀도·비양도      비양도 북측 큰여
# 2    126.507972  33.516722   G20712    F2044         제주도 북서부        용두암 낚시터
# 3    126.929083  33.434611   G20753    F2047          제주도 동부     방두곶 좌측 갯바위
# 4    126.663889  33.238694   G20775    F2048         제주도 남동부       가막코지 갯바위
# ..          ...        ...      ...      ...             ...            ...
# 970  127.107738  34.602478   G30206    F3011          득량만 부근         득량도 우측
# 971  128.348119  34.661539   G30530    F3027          연화도 부근           가마동섬
# 972  127.389611  34.751111   G30290    F3015          순천만 부근          선정 부근
# 973  126.321053  34.867865   G30045    F3003           목포 부근          모삼머리들
# 974  126.312973  33.975919   G30133    F3007            추자군도         검둥여 부근
#
#      MATERIAL       DPWT            TIDE_TIME  \
# ...

# %%
data['DPWT'].str.contains('m')
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 970     True
# 971     True
# 972     True
# 973     True
# 974     True
# Name: DPWT, Length: 975, dtype: bool

# %%
remove_arr=data['DPWT'].str.replace('m','')

# %%
data['DPWT']=remove_arr

# %%
data['DPWT'].str.contains('m')
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 970    False
# 971    False
# 972    False
# 973    False
# 974    False
# Name: DPWT, Length: 975, dtype: bool

# %%
data.to_csv('갯바위.csv', index=False)

# %%
df=pd.read_csv("./갯바위.csv")
df
# Out:
#               X          Y OBJECTID YINFO_ID            NAME       POINT_NM  \
# 0    127.453694  34.543694   G10392    F1026             나로도  내나로도 구룡마을 갯바위
# 1    126.223750  33.411694   G20695    F2043  제주도 서부·차귀도·비양도      비양도 북측 큰여
# 2    126.507972  33.516722   G20712    F2044         제주도 북서부        용두암 낚시터
# 3    126.929083  33.434611   G20753    F2047          제주도 동부     방두곶 좌측 갯바위
# 4    126.663889  33.238694   G20775    F2048         제주도 남동부       가막코지 갯바위
# ..          ...        ...      ...      ...             ...            ...
# 970  127.107738  34.602478   G30206    F3011          득량만 부근         득량도 우측
# 971  128.348119  34.661539   G30530    F3027          연화도 부근           가마동섬
# 972  127.389611  34.751111   G30290    F3015          순천만 부근          선정 부근
# 973  126.321053  34.867865   G30045    F3003           목포 부근          모삼머리들
# 974  126.312973  33.975919   G30133    F3007            추자군도         검둥여 부근
#
#      MATERIAL       DPWT            TIDE_TIME  \
# ...
