# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
data = pd.read_csv("./어종.csv")

data
# Out:
#        NO       SPEC         MEAN  Cel_min  Cel_max
# 0   F0001        가리비           잠수      NaN      NaN
# 1   F0002  가무락(모시조개)          해루질      NaN      NaN
# 2   F0003        가자미        릴찌,원투     15.0     20.0
# 3   F0004        간재미           원투      7.0     11.0
# 4   F0005         갈치           루어     16.0     18.0
# 5   F0006        감성돔     릴찌,장대,원투     17.0     19.0
# 6   F0007       갑오징어           에깅     13.0     16.0
# 7   F0008         개불          해루질      NaN      NaN
# 8   F0009          게          해루질      NaN      NaN
# 9   F0010         고동          해루질      NaN      NaN
# 10  F0011        고등어     장대,릴찌,루어     15.0     16.0
# 11  F0012         광어        릴찌,원투     12.0     16.0
# 12  F0013          굴          해루질      NaN      NaN
# 13  F0014       까막조개          해루질      NaN      NaN
# 14  F0015         꼬막          해루질      NaN      NaN
# 15  F0016       꼬시래기          해루질      NaN      NaN
# 16  F0017        꼴뚜기       에깅, 루어     11.0     13.0
# ...
